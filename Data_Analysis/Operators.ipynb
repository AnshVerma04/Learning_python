# %%
## Arthmentical Operators
a = 10
b = 20
add_result = a + b
sub_result = a - b
mult_result = a * b
div_result = a / b
 
print(add_result)
print(sub_result)
print(mult_result)
print(div_result)
# Out:
# 30
# -10
# 200
# 0.5

# %%
## Comparison Operators
## == Equal to

a = 10
b = 10

a == b
# Out:
# True

# %%
str1 = "Ansh"
str2 = "Ansh"

str1 == str2
# Out:
# True

# %%
## Not Equal to !=

str != str2
# Out:
# True

# %%
# greater than >

a = 54
b = 65

a > b
# Out:
# False

# %%
# less Than < 

print(a < b)
# Out:
# True

# %%
# greater than or equal to

Number1 = 45
Number2 = 45

print(Number1 >= Number2)
# Out:
# True

# %%
# less than or equal to

Number1 = 44
Number2 = 45

print(Number1 <= Number2)
# Out:
# True

# %%
# And

X = True
Y = True

result = X and Y
print(result)
# Out:
# True

# %%
X = False
Y = True

result = X and Y
print(result)

# %%
# OR 

X = False
Y = True

result = X or Y
print(result)
# Out:
# True

# %%
# NOT

X = False
Y = True

result = X not Y
print(result)
