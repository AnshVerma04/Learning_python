# %%
## if statement

age = 20
if age >= 18:
    print("you are allowed to vote in elections")
# Out:
# you are allowed to vote in elections

# %%
age >= 18
# Out:
# True

# %%
## else 
## the else statement executes a block of code if the condition in the if statement is false.

age = 16

if age >= 18:
    print("you are eligible for voting")
else:
    print("you are a minor")
# Out:
# you are a minor

# %%
## elif Statement 
## the elif statement allows you to check multiple condition. it stands for "else if"

age = 17

if age <13:
    print("you are a child")
elif age<18:
    print("you are a teenager")
else:
    print("you are an adult")
# Out:
# you are a teenager

# %%
## Nested condtional statements
## you can place one or more if ,elif or else statement inside another if ,elif or else statement to create nested conditional satements.

## number even,odd,negative 

num =  int(input("enter the number")) 

if num >0:
    print("the number is positive")
    if num %2 == 0:
        print("number is even")
    else:
        print("number is odd")

else:
    print("the number is zero or negative")
# Out:
# the number is positive
# number is even

# %%
## Practical Exmaples

## determine if a year is a leap year using nested condtional staement.

year = int(input("Enter the year :"))

if (year %4 == 0):
    if year %100 ==0:
        if year %400 == 0:
            print(year,"is a leap year")
        else:
            print(year,"is not a leap year")
    else:
        print(year,"is a leap year")
else:
    print(year,"is not a leap year")
# Out:
# 2026 is not a leap year

# %%
num1 = float(input("Enter the number :"))
num2 = float(input("Enter the number :"))
operations = input("Enter the operation (+,-,*,/):")

if operations == '+':
    result = num1 + num2
elif operations == '-':
    result = num1 + num2
elif operations == '*':
    result = num1 + num2
elif operations == '/':
    result = num1 + num2
    if num2 != 0:
        result = num1 / num2
    else:
        result = "Error! division by Zero"
else:
    result = "Invalid operation"

print("Result",result)
# Out:
# Result 110.0
