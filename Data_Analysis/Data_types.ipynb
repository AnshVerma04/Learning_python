# %%
## Integar Example
age = 35
type(age)
# Out:
# int

# %%
## Floating Point datatype
height = 5.8
print(type(height))
# Out:
# <class 'float'>

# %%
## String Datatype Example
Name = "Ansh"
print(type(Name))
# Out:
# <class 'str'>

# %%
## Boolean Datatype
True
type(True)
# Out:
# bool

# %%
result = "Hello" + str(5)
print(result)
# Out:
# Hello5
