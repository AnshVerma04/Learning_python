# %%
## Questions:- 01
a = int(input("Enter the value:"))
b = a
print(b)
# Out:
# 5

# %%
## Question:- 02
A = int(input("Enter the value:"))
B = int(input("Enter the value:"))
C = A
D = B
print(A,B)
# Out:
# 5 4

# %%
## Question:- 03

A = (input("Enter the value:"))
B = int(A)
print(B)
print(type(B))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 4
#       1 ## Question:- 03
#       3 A = (input("Enter the value:"))
# ----> 4 B = int(A)
#       5 print(B)
#       6 print(type(B))
#
# ValueError: invalid literal for int() with base 10: 'Ansh '

# %%
## Question:- 04

A = 10 + 20
B = 10 - 30
C = 40 * 30
D = 50 / 60
print(A,B,C,D)
# Out:
# 30 -20 1200 0.8333333333333334

# %%
## Question:- 05

A = 50
print(id(A))
# Out:
# 140717875636680

# %%
## Question:- 06

A = 10
B = 20
A == B
# Out:
# False

# %%
## Question:- 07

A = 10
B = 20
print(id(A))
print(id(B))
# Out:
# 140717875635400
# 140717875635720

# %%
## Question:- 08
A = 10 == 20
B = 20 != 50
C = 50  > 10
D = 40  < 50
E = 50 >= 40
F = 60 <= 50
print(A,B,C,D,E,F)
# Out:
# False True True True True False

# %%
## Question:- 09

num1 = 10
num2 = 10.5

Result_Sum = num1 + num2
print(Result_Sum)
print(type(Result_Sum))
# Out:
# 20.5
# <class 'float'>

# %%
## Question:- 10

a , b = 10 , 20
print(a,b)
# Out:
# 10 20
