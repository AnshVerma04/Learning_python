# %%
## Question:- 01

A = 10
B = 10
print(id(A))
print(id(B))
# Out:
# 140717875635400
# 140717875635400

# %%
## Question:- 02

A = 10
print(id(A))

B = 10
print(id(A))
# Out:
# 140717875635400
# 140717875635400

# %%
## Question:- 03

A = [1,2,3]
B = [1,2,3]
B.append(4)
print(A,B)
# Out:
# [1, 2, 3] [1, 2, 3, 4]

# %%
## Question:- 04

A = 10
A = 20
print(A)
# Out:
# 20

# %%
## Question:- 05

name = "Python"
name = "j" + name[1:]
print(name)
# Out:
# jython

# %%
## Question:- 06

x = 10
y = 20

x == y
x is y
# Out:
# False

# %%
## Question:- 07

X = None
print(type(X))
# Out:
# <class 'NoneType'>

# %%
## Question:- 08

# %%
## Question:- 09
X = 100000
Y = 100000

print(X is Y)

print(id(X))
print(id(Y))
# Out:
# True
# 140718453728456
# 140718453728456

# %%
## Question:- 10
