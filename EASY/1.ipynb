# %%
## Question:- 01
A = 10

# %%
## Question:- 02

c = "Ansh Verma"

# %%
## Question:- 03

a = 5
A = 5
add = a + A
print(add)
# Out:
# 10

# %%
## Question:- 04

a = 10
b = a
a = 15
print(a)
# Out:
# 15

# %%
## Question:- 05
a = 15; b = 20; c = 30;
print(a,b,c)
# Out:
# 15 20 30

# %%
## Question:- 06 (laksh)
a = 10
b = 15
a , b = b ,a 
print(a)
print(b)
# Out:
# 15
# 10

# %%
## Question:- 07

a = 10
b = a
c = b
print(a,b,c)
# Out:
# 10 10 10

# %%
## Question:- 08

a = 5.12
print(type(a))
# Out:
# <class 'float'>

# %%
## Questions:- 09
a = True
print(a)
# Out:
# True

# %%
## Question:- 10
A = "Ansh Verma"
print(len(A))
# Out:
# 10
